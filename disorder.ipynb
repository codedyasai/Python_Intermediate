# %% [markdown]
# <a href="https://colab.research.google.com/github/codedyasai/Python_Intermediate/blob/main/disorder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
disorder = pd.read_excel('disorder.xlsx', index_col=[0,1,2,3],header=[0,1,2],sheet_name = 5)
disorder
# Out:
#                       2018년                                                  \
#                        ADHD                   비만                  불면증
# 연령구분                 요양급여비용 입내원일수   환자수   요양급여비용 입내원일수 환자수     요양급여비용 입내원일수
# 서울 강남구 남 0~9세     188836790  3330   437  9914070   121  57          0     0
#          10~19세   563498480  8869  1111  9030550   130  63    9071590   214
#          20~29세   213248290  3485   456  5063090    62  34   80715840  2655
#          30~39세    72761750  1357   174  3278370    79  41  111038700  4220
#          40~49세    21611080   357    55  1528400    51  31   95899090  3199
# ...                     ...   ...   ...      ...   ...  ..        ...   ...
# 세종 세종시 여 60~69세           0     0     0        0     0   0   10201290   509
#          70~79세           0     0     0        0     0   0    5933020   379
#          80~89세           0     0     0        0     0   0   15137740   408
# ...

# %%
disorder.loc[('서울','강남구','남'),('2018년','ADHD','입내원일수')]['0~9세']
# Out:
# <ipython-input-84-380d138c713a>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   disorder.loc[('서울','강남구','남'),('2018년','ADHD','입내원일수')]['0~9세']
# 3330
